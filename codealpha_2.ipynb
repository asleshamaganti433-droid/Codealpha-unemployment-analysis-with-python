# %%
#Unemployment Analysis with Python
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create Sample Dataset
data = {
    'Date': pd.date_range('2020-01-01', periods=24, freq='M'),
    'Unemployment_Rate': [7.5,7.8,8.1,14.5,13.2,11.8,10.5,9.8,8.9,8.2,7.9,7.5,
                          7.0,6.8,6.5,6.2,6.0,5.9,5.8,5.7,5.6,5.5,5.4,5.3]
}

df = pd.DataFrame(data)

print(df.head())

# Line Plot
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Unemployment_Rate'], marker='o')
plt.title("Unemployment Trend")
plt.xlabel("Date")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)
plt.show()

# Statistics
print("\nSummary Statistics")
print(df.describe())

# Covid Impact
covid_period = df[df['Date']<'2021-01-01']
post_covid = df[df['Date']>='2021-01-01']

print("\nAverage During Covid:",
      covid_period['Unemployment_Rate'].mean())

print("Average After Covid:",
      post_covid['Unemployment_Rate'].mean())
# Out:
# /tmp/ipykernel_1140/1938254130.py:9: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Date': pd.date_range('2020-01-01', periods=24, freq='M'),
#         Date  Unemployment_Rate
# 0 2020-01-31                7.5
# 1 2020-02-29                7.8
# 2 2020-03-31                8.1
# 3 2020-04-30               14.5
# 4 2020-05-31               13.2
# Summary Statistics
#                       Date  Unemployment_Rate
# count                   24          24.000000
# mean   2021-01-14 09:00:00           7.808333
# min    2020-01-31 00:00:00           5.300000
# 25%    2020-07-23 06:00:00           5.875000
# 50%    2021-01-15 12:00:00           7.250000
# 75%    2021-07-07 18:00:00           8.375000
# max    2021-12-31 00:00:00          14.500000
# std                    NaN           2.521890
#
# Average During Covid: 9.641666666666667
# Average After Covid: 5.9750000000000005
